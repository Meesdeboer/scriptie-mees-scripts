# %%
from ALPR import alpr
from match_license_plate import match_license_plate_to_database
from PIL import Image
# Out:
# 2024-06-09 18:39:09.213514: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 18:39:09.213594: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 18:39:09.214887: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
IMAGE_PATH = "../test_notebooks/images/fp.png"
img = Image.open(IMAGE_PATH)
img.resize((300, 300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
try:
    result = alpr(IMAGE_PATH)
    print("Predicted license plate:",result)
    match, count = match_license_plate_to_database(result, "lp_database.txt")
    print("Matched license plate:",match)
    print("Number of matches:",count)
except:
    print("No license plates found in the image.")
# Out:
# image 1/1 /home/mees/Desktop/UVA/Scriptie/License-Plate-Recognition-Thesis/ALPR/../test_notebooks/images/fp.png: 352x640 (no detections), 940.5ms
# Speed: 9.7ms preprocess, 940.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# No license plates found in the image.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       7 except:
#       8     print("No license plates found in the image.")
# ---> 10 result
#
# NameError: name 'result' is not defined
